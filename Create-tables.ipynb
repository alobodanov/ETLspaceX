# %%
from sqlalchemy import *
from sqlalchemy.schema import CreateSchema

metadata = MetaData()
engine = create_engine('mysql://root:root@localhost:3306')
engine.execute(CreateSchema('spacex'))

# %%
engine.execute("USE spacex")
metadata = MetaData()

Rockets = Table('rockets', metadata,
    Column('id', Integer, primary_key=True),
    Column('rocket_name', String(50), nullable=False),
    Column('rocket_id', String(30)),
    Column('cost_per_launch', Integer, nullable=True),
    Column('country', String(100), nullable=True),
    Column('description', String(255), nullable=True),
    Column('rocket_type', String(255), nullable=True),
    Column('active', Integer, nullable=True)
)

Launcher = Table('launcher', metadata,
    Column('rocket_name', String(50), nullable=False),
    Column('launch_pads_id', Integer, nullable=False),
    Column('rocket_id', Integer, nullable=False),
    Column('date_utc', DateTime, nullable=True),
    Column('details', Integer, nullable=True),
    Column('flight_number', Integer, nullable=True),
    Column('year', Date, nullable=True)
)

Launchpads = Table('launch_pads', metadata,
    Column('launch_pads_id', Integer, primary_key=True),
    Column('name', Integer, primary_key=True),
    Column('region', String(30), nullable=True),
    Column('status', String(30), nullable=True),
    Column('details', String(30), nullable=True),
    Column('successful_launches', String(30), nullable=True)
)

metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in visit_create_table(self, create)
#    2834                 processed = self.process(
# -> 2835                     create_column, first_pk=column.primary_key and not first_pk
#    2836                 )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in process(self, obj, **kwargs)
#     349     def process(self, obj, **kwargs):
# --> 350         return obj._compiler_dispatch(self, **kwargs)
#     351
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in _compiler_dispatch(self, visitor, **kw)
#      90                 else:
# ---> 91                     return meth(self, **kw)
#      92
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in visit_create_column(self, create, first_pk)
#    2866
# -> 2867         text = self.get_column_specification(column, first_pk=first_pk)
#    2868         const = " ".join(
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py in get_column_specification(self, column, **kw)
#    1489             self.dialect.type_compiler.process(
# -> 1490                 column.type, type_expression=column
#    1491             ),
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in process(self, type_, **kw)
#     399     def process(self, type_, **kw):
# --> 400         return type_._compiler_dispatch(self, **kw)
#     401
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in _compiler_dispatch(self, visitor, **kw)
#      90                 else:
# ---> 91                     return meth(self, **kw)
#      92
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in visit_string(self, type_, **kw)
#    3331     def visit_string(self, type_, **kw):
# -> 3332         return self.visit_VARCHAR(type_, **kw)
#    3333
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py in visit_VARCHAR(self, type_, **kw)
#    1950             raise exc.CompileError(
# -> 1951                 "VARCHAR requires a length on dialect %s" % self.dialect.name
#    1952             )
#
# CompileError: VARCHAR requires a length on dialect mysql
#
# The above exception was the direct cause of the following exception:
#
# CompileError                              Traceback (most recent call last)
# <ipython-input-10-5b5a78716574> in <module>()
#      32 )
#      33
# ---> 34 metadata.create_all(engine)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\schema.py in create_all(self, bind, tables, checkfirst)
#    4285             bind = _bind_or_error(self)
#    4286         bind._run_visitor(
# -> 4287             ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    4288         )
#    4289
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, connection, **kwargs)
#    2031     ):
#    2032         with self._optional_conn_ctx_manager(connection) as conn:
# -> 2033             conn._run_visitor(visitorcallable, element, **kwargs)
#    2034
#    2035     class _trans_ctx(object):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, **kwargs)
#    1605
#    1606     def _run_visitor(self, visitorcallable, element, **kwargs):
# -> 1607         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    1608
#    1609
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in traverse_single(self, obj, **kw)
#     129             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     130             if meth:
# --> 131                 return meth(obj, **kw)
#     132
#     133     def iterate(self, obj):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\ddl.py in visit_metadata(self, metadata)
#     779                     create_ok=True,
#     780                     include_foreign_key_constraints=fkcs,
# --> 781                     _is_metadata_operation=True,
#     782                 )
#     783             else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in traverse_single(self, obj, **kw)
#     129             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     130             if meth:
# --> 131                 return meth(obj, **kw)
#     132
#     133     def iterate(self, obj):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\ddl.py in visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     824                 table,
#     825                 include_foreign_key_constraints=  # noqa
# --> 826                     include_foreign_key_constraints,
#     827             )
#     828             # fmt: on
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\ddl.py in _execute_on_connection(self, connection, multiparams, params)
#      70
#      71     def _execute_on_connection(self, connection, multiparams, params):
# ---> 72         return connection._execute_ddl(self, multiparams, params)
#      73
#      74     def execute(self, bind=None, target=None):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_ddl(self, ddl, multiparams, params)
#    1041             schema_translate_map=self.schema_for_object
#    1042             if not self.schema_for_object.is_default
# -> 1043             else None,
#    1044         )
#    1045         ret = self._execute_context(
#
# <string> in <lambda>(self, bind, dialect, **kw)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in compile(self, default, bind, dialect, **kw)
#     460             else:
#     461                 dialect = default.StrCompileDialect()
# --> 462         return self._compiler(dialect, bind=bind, **kw)
#     463
#     464     def _compiler(self, dialect, **kw):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\ddl.py in _compiler(self, dialect, **kw)
#      27         Dialect."""
#      28
# ---> 29         return dialect.ddl_compiler(dialect, self, **kw)
#      30
#      31
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in __init__(self, dialect, statement, bind, schema_translate_map, compile_kwargs)
#     317             if self.can_execute:
#     318                 self.execution_options = statement._execution_options
# --> 319             self.string = self.process(self.statement, **compile_kwargs)
#     320
#     321     @util.deprecated(
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in process(self, obj, **kwargs)
#     348
#     349     def process(self, obj, **kwargs):
# --> 350         return obj._compiler_dispatch(self, **kwargs)
#     351
#     352     def __str__(self):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in _compiler_dispatch(self, visitor, **kw)
#      89                     raise exc.UnsupportedCompilationError(visitor, cls)
#      90                 else:
# ---> 91                     return meth(self, **kw)
#      92
#      93         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in visit_create_table(self, create)
#    2845                     exc.CompileError(
#    2846                         util.u("(in table '%s', column '%s'): %s")
# -> 2847                         % (table.description, column.name, ce.args[0])
#    2848                     )
#    2849                 )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in visit_create_table(self, create)
#    2833             try:
#    2834                 processed = self.process(
# -> 2835                     create_column, first_pk=column.primary_key and not first_pk
#    2836                 )
#    2837                 if processed is not None:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in process(self, obj, **kwargs)
#     348
#     349     def process(self, obj, **kwargs):
# --> 350         return obj._compiler_dispatch(self, **kwargs)
#     351
#     352     def __str__(self):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in _compiler_dispatch(self, visitor, **kw)
#      89                     raise exc.UnsupportedCompilationError(visitor, cls)
#      90                 else:
# ---> 91                     return meth(self, **kw)
#      92
#      93         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in visit_create_column(self, create, first_pk)
#    2865             return None
#    2866
# -> 2867         text = self.get_column_specification(column, first_pk=first_pk)
#    2868         const = " ".join(
#    2869             self.process(constraint) for constraint in column.constraints
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py in get_column_specification(self, column, **kw)
#    1488             self.preparer.format_column(column),
#    1489             self.dialect.type_compiler.process(
# -> 1490                 column.type, type_expression=column
#    1491             ),
#    1492         ]
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in process(self, type_, **kw)
#     398
#     399     def process(self, type_, **kw):
# --> 400         return type_._compiler_dispatch(self, **kw)
#     401
#     402
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in _compiler_dispatch(self, visitor, **kw)
#      89                     raise exc.UnsupportedCompilationError(visitor, cls)
#      90                 else:
# ---> 91                     return meth(self, **kw)
#      92
#      93         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py in visit_string(self, type_, **kw)
#    3330
#    3331     def visit_string(self, type_, **kw):
# -> 3332         return self.visit_VARCHAR(type_, **kw)
#    3333
#    3334     def visit_unicode(self, type_, **kw):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py in visit_VARCHAR(self, type_, **kw)
#    1949         else:
#    1950             raise exc.CompileError(
# -> 1951                 "VARCHAR requires a length on dialect %s" % self.dialect.name
#    1952             )
#    1953
#
# CompileError: (in table 'launch_pads', column 'successful_launches'): VARCHAR requires a length on dialect mysql
